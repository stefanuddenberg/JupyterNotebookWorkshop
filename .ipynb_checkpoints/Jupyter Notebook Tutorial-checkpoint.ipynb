# %% [markdown]
# # Jupyter Notebook Tutorial

# %% [markdown]
# ## To Do
# - Python markdown?
# - Debugging tutorial?
# - Even more pandas?

# %% [markdown]
# ## Getting set up
#
# 1. [Install Anaconda](https://www.anaconda.com/download/)
#     - I'd recommend getting the latest version of Python (version 3.6 at time of writing)
#     <br><br>
#
# 2. Install necessary packages with:
#     - `pip install package_name`
#     - You might have to preface that with `sudo` if you're on a Mac.
#     <br><br>
#
# 3. You're probably going to want the following packages (though some may already be installed via Anaconda):
#     - jupyter
#     - jupyter_contrib_nbextensions
#         - run the following command for this after install: `jupyter contrib nbextension install --user`
#     - jupyterthemes
#         - use if you're not happy with the default aesthetics of the notebook
#         - run at terminal for (most of) my aesthetic setup: `jt -t grade3 -fs 12 -tfs 12 -nfs 115 -cellw 88% -T`
#         - if you don't like it, you can always go back to the default: `jt -r`
#     - matplotlib
#     - nbopen (esp. on Windows — lets you double-click on notebooks to open them!)
#     - numpy
#     - pandas
#     - prettypandas
#     - pymatbridge
#         - for using MATLAB
#         - step 2: go to *matlabroot*\extern\engines\python and run `python3 setup.py install`
#     - rpy2
#         - for using R
#         - [See here for further instructions](https://github.com/IRkernel/IRkernel)
#     - scipy
#     - seaborn
#     - statsmodels
#     - wes (optional package for Wes Anderson-style color palettes)
#     <br><br>
#
# 4. Run Jupyter notebook from terminal or cmd:
#     - `jupyter notebook`
#     - Make sure to cd into the directory you want to run it in (or at least a directory *higher* than the one you want; you can't go back up from within the notebook instance!)
#     <br><br>
#
# 5. Enable your favorite nbextensions (below are mine)
#     - table_beautifier
#     - Table of Contents (2), with auto-number, sidebar, widen display, display toc as navigation menu, move title and menu left instead of center, and collapse
#         - can export notebook to HTML with table of contents with: `jupyter nbconvert --to html_toc FILENAME.ipynb`
#     - Collapsible Headings, with add a control, adjust size of toggle controls, gray bracketed ellipsis, command-mode, collapse with ToC2
#     - Variable inspector
#     - Codefolding
#     - Chrome clipboard
#     - Codefolding in editor
#     - contrib_nbextensions_help_item
#     - nbextensions dashboard tab
#     - Python Markdown
#         - must be trusted notebook to use properly -- enable trust at top-right of notebook
#     - Tree Filter

# %% [markdown]
# # Markdown tutorial

# %% [markdown]
# # Headings are made with a preceding "#" symbol.
#
# ## Subheadings with "##"
# ### Sub-subheadings with "###" (and so on)
# <br><br>
#
# #### White space
# Force new blank lines with "< br >" (without quotes or spaces between the characters)
# <br>
#
# #### Emphasis
# *Italics* are made by surrounding a word or phrase with asterisks, or with underscores, _like so_.
# <br>
#
# **Bold** words are made by surrounding a word or phrase with 2 asterisks on each end.
# <br>
#
# **_You can make a phrase both bold and Italic_** by combining the above!
# <br><br>
#
# #### Unordered Lists
# - Dashes make bullets
#     - And tabbing first makes a sub-bullet
#         - You can also just use a single space instead of a tab character; just be consistent.
# <br><br>
#
# #### Ordered Lists
# 1. You can make ordered lists with a number followed by a dot.
# 2. Here's another point.
# <br><br>
#
# #### Blockquotes
# > Put a ">" before a line to turn it into a blockquote.
# <br><br>
#
# #### Code
# unhighlighted code goes between backticks: `this is code`
# <br>
#
# And you can define blocks of code by sandwiching them between 3 backticks (you can even get syntax highlighting!)
# <br>
#
# ```python
# x = [1, 2, 3]
# for i in x:
#     print(i)
# ```
# <br>
#
# #### Hyperlinks and images
# [Hyperlinks go in square brackets](https://www.wikiwand.com/en/Kaizen), with the link itself going in parentheses immediately after (no whitespace allowed between neighboring brackets)!
# <br><br>
#
# Images with are just like hyperlinks, but with an exclamation point in front. The writing in square brackets serves as the alt-text for the image.
# ![Yale Psychology Department](http://psychology.yale.edu/sites/default/files/styles/adaptive/public/yalearchitecture_sss2.jpg?itok=jc7f5qWZ)
# <br><br>

# %% [markdown]
# ## Embed HTML, including video

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Magic commands

# %% [markdown]
# See all commands.

# %%
# %lsmagic

# %% [markdown]
# <br>
# And run terminal commands directly with "!"

# %%
# !pip list

# %% [markdown]
# ## Data analysis with pandas

# %% [markdown]
# ### In-depth pandas tutorial
# [Giant pandas tutorial](https://www.youtube.com/watch?v=mwt3BTkStNg&t=3s) and [attendant notes](https://github.com/chendaniely/scipy-2017-tutorial-pandas![image.png](attachment:image.png).

# %% [markdown]
# ### Setup
# Allow plots in the notebook itself, and enable some helpful functions.

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') # because we are adults

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' # high-res graphs
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':'tight'} # no extra white space
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# <br>
# Import example data.

# %%
import pandas as pd
import seaborn as sns

data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Data exploration

# %% [markdown]
# Change default graph appearance to something you like. [See here for full list of available built-in styles.](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)

# %%
sns.set_style("ticks") # e.g., ggplot, whitegrid, etc.

# %% [markdown]
# <br>
# Plot histograms of tips grouped by sex side by side. Make sure both have the same x and y limits.

# %%
data['tip'].hist(by=data['sex'], sharex=True, sharey=True)
sns.despine() # remove top and right side of box

plt.show() # somewhat redundant in this context, but suppresses annoying text output.

# %% [markdown]
# Overlaid histograms.

# %%
grouped_by_sex = data.groupby('sex')

# You can also add several arguments below like bins=20, or normed=True
figure, axes = grouped_by_sex['tip'].plot(kind='hist', normed=False, alpha=.5, legend=True) 

# Re-label axes, move axes to right-middle
axes.legend(['Men', 'Women'], loc=(0.75, 0.5)) 

sns.despine() 
plt.show()

# %% [markdown]
# Show summary stats for the sexes.

# %%
grouped_by_sex['tip'].describe()
# Out:
#         count      mean       std  min  25%   50%   75%   max
# sex
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5

# %% [markdown]
# ### ANOVA
# <br>
# Perform an ANOVA, using R-style syntax.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = 'tip ~ sex * smoker * total_bill'
lm = ols(model, data=data).fit()
table = sm.stats.anova_lm(lm, typ=2)

display(table)
# Out:
#                            sum_sq     df           F        PR(>F)
# sex                      0.000077    1.0    0.000080  9.928825e-01
# smoker                   1.355188    1.0    1.400472  2.378352e-01
# sex:smoker               1.181731    1.0    1.221220  2.702468e-01
# total_bill             212.691658    1.0  219.798892  1.379847e-35
# sex:total_bill           0.257702    1.0    0.266314  6.062986e-01
# smoker:total_bill       19.286030    1.0   19.930485  1.244839e-05
# sex:smoker:total_bill    0.047207    1.0    0.048784  8.253839e-01
# Residual               228.368900  236.0         NaN           NaN

# %% [markdown]
# <br>
# Make the table prettier and more intelligible.

# %%
from prettypandas import PrettyPandas 

def color_significant_green(val):
    if val < .05: color = 'green'
    else: color = 'black'
    return 'color: %s' % color

def bold_significant(val):
    if val < .05: font_weight = 'bold'
    else: font_weight = 'normal'
    return 'font-weight: %s' % font_weight

t = PrettyPandas(table)
(
    t.applymap(color_significant_green, subset=['PR(>F)'])
    .applymap(bold_significant, subset=['PR(>F)'])
    .format("{:.3f}", subset=['sum_sq', 'F', 'PR(>F)'])
)
# Out:
# <style  type="text/css" >
#     #T_da92397e_b7cc_11e7_9f46_7085c23c481d th {
#           background: #eee;
#           font-weight: 500;
#     }    #T_da92397e_b7cc_11e7_9f46_7085c23c481d td {
#           text-align: right;
#           min-width: 3em;
#     }    #T_da92397e_b7cc_11e7_9f46_7085c23c481d * {
#           border-color: #c0c0c0;
#     }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow0_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow1_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow2_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow3_col3 {
#             color:  green;
#             font-weight:  bold;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow4_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow5_col3 {
#             color:  green;
#             font-weight:  bold;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow6_col3 {
#             color:  black;
#             font-weight:  normal;
#         }    #T_da92397e_b7cc_11e7_9f46_7085c23c481drow7_col3 {
#             color:  black;
#             font-weight:  normal;
#         }</style>
# <table id="T_da92397e_b7cc_11e7_9f46_7085c23c481d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >sum_sq</th>
#         <th class="col_heading level0 col1" >df</th>
#         <th class="col_heading level0 col2" >F</th>
#         <th class="col_heading level0 col3" >PR(>F)</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row0" class="row_heading level0 row0" >sex</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow0_col0" class="data row0 col0" >0.000</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow0_col1" class="data row0 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow0_col2" class="data row0 col2" >0.000</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow0_col3" class="data row0 col3" >0.993</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row1" class="row_heading level0 row1" >smoker</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow1_col0" class="data row1 col0" >1.355</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow1_col1" class="data row1 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow1_col2" class="data row1 col2" >1.400</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow1_col3" class="data row1 col3" >0.238</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row2" class="row_heading level0 row2" >sex:smoker</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow2_col0" class="data row2 col0" >1.182</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow2_col1" class="data row2 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow2_col2" class="data row2 col2" >1.221</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow2_col3" class="data row2 col3" >0.270</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row3" class="row_heading level0 row3" >total_bill</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow3_col0" class="data row3 col0" >212.692</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow3_col1" class="data row3 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow3_col2" class="data row3 col2" >219.799</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow3_col3" class="data row3 col3" >0.000</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row4" class="row_heading level0 row4" >sex:total_bill</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow4_col0" class="data row4 col0" >0.258</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow4_col1" class="data row4 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow4_col2" class="data row4 col2" >0.266</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow4_col3" class="data row4 col3" >0.606</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row5" class="row_heading level0 row5" >smoker:total_bill</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow5_col0" class="data row5 col0" >19.286</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow5_col1" class="data row5 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow5_col2" class="data row5 col2" >19.930</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow5_col3" class="data row5 col3" >0.000</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row6" class="row_heading level0 row6" >sex:smoker:total_bill</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow6_col0" class="data row6 col0" >0.047</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow6_col1" class="data row6 col1" >1</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow6_col2" class="data row6 col2" >0.049</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow6_col3" class="data row6 col3" >0.825</td>
#     </tr>    <tr>
#         <th id="T_da92397e_b7cc_11e7_9f46_7085c23c481dlevel0_row7" class="row_heading level0 row7" >Residual</th>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow7_col0" class="data row7 col0" >228.369</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow7_col1" class="data row7 col1" >236</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow7_col2" class="data row7 col2" >nan</td>
#         <td id="T_da92397e_b7cc_11e7_9f46_7085c23c481drow7_col3" class="data row7 col3" >nan</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### T-tests

# %%
from numpy import sqrt
from scipy.stats import ttest_ind

def cohens_d(t, n):
    return 2*t / sqrt(n - 2)

# Set up empty results table
columns = ['n', 't', 'p', 'd']
index = []
results = pd.DataFrame(index=index, columns=columns)

# get data for t-test
male_tips = data[data['sex']=='Male']['tip']
female_tips = data[data['sex']=='Female']['tip']

# perform t-test and surrounding calculations
n = male_tips.count() + female_tips.count()
t, p = ttest_ind(male_tips, female_tips)
d = cohens_d(t, n)

# add data to table
comparison = 'Male vs. Female'
results.loc[comparison] = [n, t, p, d]

# output pretty table
r = PrettyPandas(results)
(
    r.applymap(color_significant_green, subset=['p'])
    .applymap(bold_significant, subset=['p'])
    .format("{:.3f}", subset=['t', 'p', 'd'])
)
# Out:
# <style  type="text/css" >
#     #T_597c6c9c_b7cf_11e7_be95_7085c23c481d th {
#           background: #eee;
#           font-weight: 500;
#     }    #T_597c6c9c_b7cf_11e7_be95_7085c23c481d td {
#           text-align: right;
#           min-width: 3em;
#     }    #T_597c6c9c_b7cf_11e7_be95_7085c23c481d * {
#           border-color: #c0c0c0;
#     }    #T_597c6c9c_b7cf_11e7_be95_7085c23c481drow0_col2 {
#             color:  black;
#             font-weight:  normal;
#         }</style>
# <table id="T_597c6c9c_b7cf_11e7_be95_7085c23c481d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >n</th>
#         <th class="col_heading level0 col1" >t</th>
#         <th class="col_heading level0 col2" >p</th>
#         <th class="col_heading level0 col3" >d</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_597c6c9c_b7cf_11e7_be95_7085c23c481dlevel0_row0" class="row_heading level0 row0" >Male vs. Female</th>
#         <td id="T_597c6c9c_b7cf_11e7_be95_7085c23c481drow0_col0" class="data row0 col0" >244</td>
#         <td id="T_597c6c9c_b7cf_11e7_be95_7085c23c481drow0_col1" class="data row0 col1" >1.388</td>
#         <td id="T_597c6c9c_b7cf_11e7_be95_7085c23c481drow0_col2" class="data row0 col2" >0.166</td>
#         <td id="T_597c6c9c_b7cf_11e7_be95_7085c23c481drow0_col3" class="data row0 col3" >0.178</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### Plots

# %% [markdown]
# Plot simple line graph with sample data.

# %%
line_data = range(1,10)

plt.figure()
plt.title("Example Graph", size="xx-large")
plt.xlabel("X-Axis Label", size="x-large")
plt.ylabel("Y-Axis Label", size="x-large")
plt.xlim(0,10)
plt.ylim(0,10)
plt.plot(line_data, 'b*-', markersize=10, linewidth=3, label='Sample Data') # b*- means blue star marker with line
plt.tick_params(axis="both", which="major", labelsize=14)
plt.legend(loc=(0.25, 0.75), scatterpoints=1)
plt.show()

# %% [markdown]
# Plot violin plot with overlaid beeswarm plot.

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

ax = sns.violinplot(x="day", y="total_bill", data=data, inner=None)
ax = sns.swarmplot(x="day", y="total_bill", data=data,
                   color="white", edgecolor="gray")

# %% [markdown]
# ## Run R code
#
# Note that this requires running from a Python 3 instance of Jupyter (in my case, at least).

# %%
import pandas as pd
df = pd.DataFrame({'Letter': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                   'X': [4, 3, 5, 2, 1, 7, 7, 5, 9],
                   'Y': [0, 4, 3, 6, 7, 10, 11, 9, 13],
                   'Z': [1, 2, 3, 1, 2, 3, 1, 2, 3]})

# %% [markdown]
# <br>
# Load extension allowing one to run R code from within a Python notebook.

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# <br>
# Do stuff in R with cell or line magics.

# %%
# %%R -i df
# library("ggplot2")
# ggplot(data = df) + geom_point(aes(x = X, y = Y, color = Letter, size = Z))

# %% [markdown]
# ## Run MATLAB code

# %% [markdown]
# Load MATLAB extension for running MATLAB code within a Python notebook.

# %%
# %load_ext pymatbridge
# Out:
# C:\Users\sdu2\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\nbformat.py:13: ShimWarning: The `IPython.nbformat` package has been deprecated since IPython 4.0. You should import from nbformat instead.
#   "You should import from nbformat instead.", ShimWarning)
# Starting MATLAB on ZMQ socket tcp://127.0.0.1:51902
# Send 'exit' command to kill the server
# ...........MATLAB started and connected!

# %% [markdown]
# <br>
# Do MATLAB things with line or cell magics.

# %%
# %%matlab
# a = linspace(0.01,6*pi,100);
# plot(sin(a))
# grid on
# hold on
# plot(cos(a),'r')

# %% [markdown]
# Exit MATLAB when done.

# %%
# %unload_ext pymatbridge
# Out:
# MATLAB closed
